# %%
# %display latex

# %%
x = var('x')
y = var('y')
t = var('t')

# %%
f = log(x)*y + e^(x^2)
f
# Out:
# y*log(x) + e^(x^2)

# %%
f.derivative(x)
# Out:
# 2*x*e^(x^2) + y/x

# %%
g = f.integral(x)
g
# Out:
# (x*log(x) - x)*y - 1/2*I*sqrt(pi)*erf(I*x)

# %%
limit(g, x=0)
# Out:
# 0

# %%
from sympy import Curve, line_integrate
C = Curve([e**t + 1, e**t - 1], (t, 0, ln(2)))
line_integrate(x + y, C, [x, y])
# Out:
# 3*sqrt(2)

# %%
plot(x**2)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
from sympy.plotting import plot3d_parametric_line
t = var('t')
alpha = [cos(t), sin(t), t]
plot3d_parametric_line(*alpha)
# Out:
# <html><script type="math/tex; mode=display">\newcommand{\Bold}[1]{\mathbf{#1}}\begin{array}{l}
# \verb|Plot|\phantom{\verb!x!}\verb|object|\phantom{\verb!x!}\verb|containing:|\\
# \verb|[0]:|\phantom{\verb!x!}\verb|3D|\phantom{\verb!x!}\verb|parametric|\phantom{\verb!x!}\verb|cartesian|\phantom{\verb!x!}\verb|line:|\phantom{\verb!x!}\verb|(cos(t),|\phantom{\verb!x!}\verb|sin(t),|\phantom{\verb!x!}\verb|t)|\phantom{\verb!x!}\verb|for|\phantom{\verb!x!}\verb|t|\phantom{\verb!x!}\verb|over|\phantom{\verb!x!}\verb|(-10.0,|\phantom{\verb!x!}\verb|10.0)|
# \end{array}</script></html>

# %%
s=vector((t,cos(t),0))
ds=diff(s,t)
ds
# Out:
# (1, -sin(t), 0)

# %%
f(x, y) = x^2 + x*y + y^2 - 6*x + 2
f.gradient()
# Out:
# (x, y) |--> (2*x + y - 6, x + 2*y)

# %%
f(x,y)=x^2*y
f.integrate(x, y/4, 3).integrate(y, 0, 12)
# Out:
# 1944/5

# %%
m = matrix([[1,1], [1,2]])
m
# Out:
# [1 1]
# [1 2]

# %%
m.inverse()
# Out:
# [ 2 -1]
# [-1  1]

# %%
v = vector([1,1])
v
# Out:
# (1, 1)

# %%
m * v
# Out:
# (2, 3)
